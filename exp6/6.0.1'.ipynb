# %% [markdown]
# # Preferential Attachment Graph with different steps (linear, naive)

# %%
import sys

sys.path.append('/Users/huberyhu/Desktop/SURP/im_deinfluence/model_code')

import networkx as nx
import experiment_framework as ef
import copy

# %%
G = nx.barabasi_albert_graph(2000, 2)

# %%
model = ef.run_influence_cascade(G, num_influencers=20, steps=3, selection_method='random')

# Evaluate the influence and deinfluence
num_influenced = model.evaluate_influence()
num_deinfluenced = model.evaluate_deinfluence()
num_susceptible = model.evaluate_susceptible()

# Create a deep copy of the model
model_fixed_influencers = copy.deepcopy(model)

# Evaluate the influence and deinfluence
num_influenced = model_fixed_influencers.evaluate_influence()
num_deinfluenced = model_fixed_influencers.evaluate_deinfluence()
num_susceptible = model_fixed_influencers.evaluate_susceptible()

print(f"Number of influenced nodes: {num_influenced}")
print(f"Number of deinfluenced nodes: {num_deinfluenced}")
print(f"Number of susceptible nodes: {num_susceptible}")
print('influencer', model.selected_influencers)
# Out:
# Number of influenced nodes: 659
# Number of deinfluenced nodes: 0
# Number of susceptible nodes: 1341
# influencer {1025, 898, 390, 1678, 1441, 931, 1828, 1060, 182, 1981, 1086, 446, 458, 330, 1743, 1615, 976, 595, 1506, 748}

# %% [markdown]
# # Cascade Step = 2

# %%
budget_list = list(range(1, 201))
deinfluencers_list = ef.select_deinfluencers_budget_naive(budget_list, model_fixed_influencers,'budget_linear')
results = ef.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=2, steps=3)
ef.plot_deinfluencer_results_exp2(results, G)

# %% [markdown]
# # Cascade Step = 3

# %%
budget_list = list(range(1, 201))
deinfluencers_list = ef.select_deinfluencers_budget_naive(budget_list, model_fixed_influencers,'budget_linear')
results = ef.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=3)
ef.plot_deinfluencer_results_exp2(results, G)

# %% [markdown]
# # Cascade step = 4

# %%
budget_list = list(range(1, 201))
deinfluencers_list = ef.select_deinfluencers_budget_naive(budget_list, model_fixed_influencers,'budget_linear')
results = ef.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=4, steps=3)
ef.plot_deinfluencer_results_exp2(results, G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 budget_list = list(range(1, 201))
#       2 deinfluencers_list = ef.select_deinfluencers_budget_naive(budget_list, model_fixed_influencers,'budget_linear')
# ----> 3 results = ef.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=4, steps=3)
#       4 ef.plot_deinfluencer_results_exp2(results, G)
#
# File ~/Desktop/SURP/im_deinfluence/model_code/experiment_framework.py:196, in average_results_simple(deinfluencers_list, model, num_runs, steps)
#     194 for _ in range(num_runs):
#     195     shuffled_deinfluencers_methods = {method: shuffle_deinfluencers(model, k, deinfluencers) if method in ['Random','High Degree', 'Low Degree'] else deinfluencers for method, deinfluencers in deinfluencers_methods.items()}
# --> 196     results = {
#     197         method: count_deinfluenced(model, deinfluencers, num_runs, steps)
#     198         for method, deinfluencers in shuffled_deinfluencers_methods.items()
#     199     }
#     201     for method, result in results.items():
#     202         cumulative_results[k][method] = (
#     203             cumulative_results[k][method][0] + result[0],
#     204             cumulative_results[k][method][1] + result[1],
#     205             {key: cumulative_results[k][method][2][key] + result[2][key] for key in result[2]}
#     206         )
#
# File ~/Desktop/SURP/im_deinfluence/model_code/experiment_framework.py:197, in <dictcomp>(.0)
#     194 for _ in range(num_runs):
#     195     shuffled_deinfluencers_methods = {method: shuffle_deinfluencers(model, k, deinfluencers) if method in ['Random','High Degree', 'Low Degree'] else deinfluencers for method, deinfluencers in deinfluencers_methods.items()}
#     196     results = {
# --> 197         method: count_deinfluenced(model, deinfluencers, num_runs, steps)
#     198         for method, deinfluencers in shuffled_deinfluencers_methods.items()
#     199     }
#     201     for method, result in results.items():
#     202         cumulative_results[k][method] = (
#     203             cumulative_results[k][method][0] + result[0],
#     204             cumulative_results[k][method][1] + result[1],
#     205             {key: cumulative_results[k][method][2][key] + result[2][key] for key in result[2]}
#     206         )
#
# File ~/Desktop/SURP/im_deinfluence/model_code/experiment_framework.py:139, in count_deinfluenced(model, deinfluencers, num_runs, steps)
#     137 model.reset_transition_counts()
#     138 model.set_deinfluencers(deinfluencers)
# --> 139 model.run_cascade(steps)
#     141 total_deinfluenced += model.evaluate_deinfluence()
#     142 total_influenced += model.evaluate_influence()
#
# File ~/Desktop/SURP/im_deinfluence/model_code/fast_model_improved.py:159, in InfluenceDeinfluenceModel.run_cascade(self, steps)
#     156 def run_cascade(self, steps):
#     157     #self.pre_determine_active_edges()
#     158     for _ in range(steps):
# --> 159         self.pre_determine_active_edges()
#     160         self.spread_influence()
#
# File ~/Desktop/SURP/im_deinfluence/model_code/fast_model_improved.py:91, in InfluenceDeinfluenceModel.pre_determine_active_edges(self)
#      88 for neighbor in self.graph.neighbors(node):
#      89     edge = (node, neighbor)
#      90     if (self.graph.nodes[neighbor]['state'] == 'S' and
# ---> 91         random.random() < self.graph[node][neighbor]['p_is'] and
#      92         edge not in self.attempted_influence):
#      93         self.active_edges.add(edge)
#      94         self.attempted_influence.add(edge)  # Mark edge as having attempted influence
#
# KeyboardInterrupt:

# %% [markdown]
# # Have larger range, step = 3

# %%
budget_list = list(range(1, 601, 5))
deinfluencers_list = ef.select_deinfluencers_budget_naive(budget_list, model_fixed_influencers,'budget_linear')
results = ef.average_results_simple(deinfluencers_list, model_fixed_influencers, num_runs=3, steps=3)
ef.plot_deinfluencer_results_exp2(results, G)
